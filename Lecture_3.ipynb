# %% [markdown]
# <a href="https://colab.research.google.com/github/mustafaerdikararmaz/python_dersleri/blob/main/Lecture_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
sözlük1 = {"sıfır":0,"bir":1,"iki":2,"üç":3}

# %%
sözlük1["sıfır"]
# Out:
# 0

# %%
a = {"bir" : [1,2,3,4], "iki": [[1,2],[3,4],[5,6]],"üç" : 15}

# %%
print(a["bir"][3])
# Out:
# 4

# %%
a["üç"] = a["üç"] + 5
a["üç"] += 5

# %%
sözlük1.values()
# Out:
# dict_values([0, 1, 2, 3])

# %%
type(sözlük1.values())
# Out:
# dict_values

# %%
sözlük1.keys()
# Out:
# dict_keys(['sıfır', 'bir', 'iki', 'üç'])

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-13-df5be4df4bbf> in <module>()
# ----> 1 sözlük1.values(0)
#
# TypeError: values() takes no arguments (1 given)

# %%
2 > 1
# Out:
# True

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
a = 2
b = 3
c = 4
print(a+b+c)
# Out:
# 9

# %%
a = 3

if (a == 2):
    print(a)

print("Rumeysa")

if (a != 2):
  print(a)
  print("Danish")
# Out:
# Rumeysa
# 3
# Danish

# %%
print("18 yaşından küçükler giremez")
yaş = int(input("yaşınızı giriniz"))

if(yaş>18 and yaş<25):
  if(input("id yanınızda mı?") == "Evet"):
    print("hoş geldiniz")
  elif(input("passport yanında mı?") == "Evet"):
    print("Hoşgeldiniz")
  else:
    print("İçeriye giremezsiniz!")
    
else:
  print("İçeriye giremezsiniz!")
# Out:
# 18 yaşından küçükler giremez
# yaşınızı giriniz26
# İçeriye giremezsiniz!
